# %%
import os
import easyocr
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
img_path = 'Whiteboards-11/test/images/ASMR-Teacher---Relaxing-English-Vocabulary-Lesson_mp4-24_jpg.rf.306714555332437f904adac761d3cf73.jpg'
img = cv2.imread(img_path)

# %%
reader = easyocr.Reader(['en'])

# %%
result = reader.readtext(np.array(Image.open(img_path)),paragraph="False")

# %%
Image.open(img_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %%
result
# Out:
# [[[[236, 190], [606, 190], [606, 304], [236, 304]],
#   'Recalctrant Odj: Stubborn rebellous obstinate , disobed; antoryms  Ogreeable , Complant , Obedient unruly Recalutrant']]

# %%
np.array(img)
# Out:
# array(None, dtype=object)

# %%
Image(img_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 Image(img_path)
#
# TypeError: 'module' object is not callable

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\Dell_assessment\\whiteboard_detection_and_text_identification\\yolov5'
